# %% [markdown]
# Part One of the Weather API Project

# %%
import requests
import pandas as pd

# %%
baseurl = "http://api.weatherapi.com/v1"
davy_key = "API Key Here"

# %%
# http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
city = 'Lexington'
baseurl = f"http://api.weatherapi.com/v1/current.json?key={davy_key}&q={city}"
response = requests.get(baseurl)

response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Lexington-Fayette',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.0497,
#   'lon': -84.4586,
#   'tz_id': 'America/New_York',
#   'localtime_epoch': 1767491965,
#   'localtime': '2026-01-03 20:59'},
#  'current': {'last_updated_epoch': 1767491100,
#   'last_updated': '2026-01-03 20:45',
#   'temp_c': -2.2,
#   'temp_f': 28.0,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 6.9,
#   'wind_kph': 11.2,
#   'wind_degree': 58,
#   'wind_dir': 'ENE',
#   'pressure_mb': 1016.0,
#   'pressure_in': 29.99,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 65,
#   'cloud': 0,
#   'feelslike_c': -6.3,
#   'feelslike_f': 20.7,
#   'windchill_c': -1.9,
#   'windchill_f': 28.7,
#   'heatindex_c': 0.4,
#   'heatindex_f': 32.7,
#   'dewpoint_c': -4.8,
#   'dewpoint_f': 23.3,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
# ...

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f, humidity
# Out:
# (28.0, 65)

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={davy_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f"Weather for {location['name']}, {location['region']}")
        print(f"Temperature: {current['temp_f']} F / {current['temp_c']} C")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']} mph")

    else:
        print(f"Error fetching data for {city}: {response.status_code}")

# %%
get_weather("Lexington")
# Out:
# Weather for Lexington-Fayette, Kentucky
# Temperature: 28.0 F / -2.2 C
# Condition: Clear
# Humidity: 65%
# Wind Speed: 6.9 mph

# %%
get_weather("Colorado Springs")
# Out:
# Weather for Colorado Springs, Colorado
# Temperature: 46.0 F / 7.8 C
# Condition: Partly cloudy
# Humidity: 42%
# Wind Speed: 2.9 mph

# %%
get_weather("Louisville")
# Out:
# Weather for Louisville, Kentucky
# Temperature: 30.9 F / -0.6 C
# Condition: Clear
# Humidity: 66%
# Wind Speed: 4.0 mph

# %%
cities = ["Lexington", "Louisville", "Morehead", "London", "Somerset"]
weather_data = []

for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={davy_key}&q={city}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            "city": data['location']['name'],
            "Temperature": data['current']['temp_f'],
            "Condition": data['current']['condition']['text'],
            "Humidity": data['current']['humidity'],
            "Wind Speed": data['current']['wind_mph']   })
    else:
        print(f"Error fetching data")

# %%
weather_data
# Out:
# [{'city': 'Lexington-Fayette',
#   'Temperature': 28.0,
#   'Condition': 'Clear',
#   'Humidity': 65,
#   'Wind Speed': 6.9},
#  {'city': 'Louisville',
#   'Temperature': 30.9,
#   'Condition': 'Clear',
#   'Humidity': 66,
#   'Wind Speed': 4.0},
#  {'city': 'Morehead',
#   'Temperature': 83.8,
#   'Condition': 'Cloudy',
#   'Humidity': 72,
#   'Wind Speed': 7.8},
#  {'city': 'London',
#   'Temperature': 26.8,
#   'Condition': 'Clear',
#   'Humidity': 80,
#   'Wind Speed': 7.4},
#  {'city': 'Somerset West',
#   'Temperature': 69.8,
#   'Condition': 'Clear',
#   'Humidity': 69,
#   'Wind Speed': 13.0}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#                 city  Temperature Condition  Humidity  Wind Speed
# 0  Lexington-Fayette         28.0     Clear        65         6.9
# 1         Louisville         30.9     Clear        66         4.0
# 2           Morehead         83.8    Cloudy        72         7.8
# 3             London         26.8     Clear        80         7.4
# 4      Somerset West         69.8     Clear        69        13.0

# %%
weather_df.to_csv("sample_weather_data.csv", index=False)
