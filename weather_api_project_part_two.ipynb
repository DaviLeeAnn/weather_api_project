# %% [markdown]
# Part two of the Weather API Project

# %%
import requests
import pandas as pd
from datetime import datetime

# %%
api_key = "cd26637cc9c447bfa5412628260401"
baseurl = "http://api.weatherapi.com/v1/"
# f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
city = "Lexington"

# %%
response = requests.get(f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}")
response.status_code
# Out:
# 200

# %%
data = response.json()
data['current']
# Out:
# {'last_updated_epoch': 1767492900,
#  'last_updated': '2026-01-03 21:15',
#  'temp_c': -2.2,
#  'temp_f': 28.0,
#  'is_day': 0,
#  'condition': {'text': 'Clear',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#   'code': 1000},
#  'wind_mph': 6.0,
#  'wind_kph': 9.7,
#  'wind_degree': 61,
#  'wind_dir': 'ENE',
#  'pressure_mb': 1016.0,
#  'pressure_in': 30.0,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 65,
#  'cloud': 0,
#  'feelslike_c': -5.9,
#  'feelslike_f': 21.5,
#  'windchill_c': -2.0,
#  'windchill_f': 28.4,
#  'heatindex_c': -0.2,
#  'heatindex_f': 31.6,
#  'dewpoint_c': -4.3,
#  'dewpoint_f': 24.3,
#  'vis_km': 16.0,
#  'vis_miles': 9.0,
#  'uv': 0.0,
#  'gust_mph': 12.5,
#  'gust_kph': 20.1,
#  'short_rad': 0,
#  'diff_rad': 0,
#  'dni': 0,
#  'gti': 0}

# %%
forecast_url = f"{baseurl}forecast.json?key={api_key}&q={city}&days=3"
forecast_response = requests.get(forecast_url)
forecast_response.status_code
# Out:
# 200

# %%
forecast_data = forecast_response.json()
forecast = forecast_data['forecast']['forecastday']

# %%
forecast_3_days_summary = []
for day in forecast:
    forecast_3_days_summary.append(f"{day['date']}: High {day['day']['maxtemp_f']}F, Low {day['day']['mintemp_f']}F - {day['day']['condition']['text']}")

# %%
forecast_3_days_summary
# Out:
# ['2026-01-03: High 40.3F, Low 29.5F - Sunny',
#  '2026-01-04: High 43.7F, Low 25.3F - Partly Cloudy ',
#  '2026-01-05: High 55.0F, Low 28.9F - Sunny']
